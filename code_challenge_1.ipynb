# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
import seaborn as sns
pd.options.display.float_format = '{:.4f}'.format
sns.set_style('whitegrid')

# %%
start = "2014-10-01"
end = "2021-05-31"
symbol = ["GE", "Reliance.NS"]

# %%
df = yf.download(symbol, start=start, end=end)
df
# Out:
# [*********************100%%**********************]  2 of 2 completed
#            Adj Close                Close                 High              \
#                   GE RELIANCE.NS       GE RELIANCE.NS       GE RELIANCE.NS
# Date
# 2014-10-01  129.5000    434.9534 151.0839    459.2468 152.9454    468.3604
# 2014-10-02  129.2941         NaN 150.8437         NaN 151.6243         NaN
# 2014-10-03  130.7353         NaN 152.5251         NaN 152.7052         NaN
# 2014-10-06  129.8089         NaN 151.4442         NaN 153.9062         NaN
# 2014-10-07  127.6985    434.4608 148.9822    458.7267 151.2640    463.0606
# ...              ...         ...      ...         ...      ...         ...
# 2021-05-24   81.5654   1966.3954  82.3107   1985.6500  83.1226   2009.8000
# 2021-05-25   81.1941   1944.1136  81.9360   1963.1500  82.9977   1997.0000
# 2021-05-26   82.9269   1950.9468  83.6846   1970.0500  83.8720   1979.5000
# 2021-05-27   88.8061   1956.9379  89.6175   1976.1000  89.9297   1993.0000
# 2021-05-28   87.0114   2074.4871  87.8064   2094.8000  89.5550   2105.0000
#
#                 Low                 Open                    Volume  \
#                  GE RELIANCE.NS       GE RELIANCE.NS            GE
# Date
# 2014-10-01 150.6035    458.6524 152.7052    467.3698  7007782.0000
# 2014-10-02 150.1832         NaN 151.2640         NaN  4745955.0000
# 2014-10-03 151.0238         NaN 151.8645         NaN  3606723.0000
# 2014-10-06 150.5434         NaN 153.7261         NaN  5077933.0000
# 2014-10-07 148.9221    457.3894 150.7236    459.2716  5326495.0000
# ...             ...         ...      ...         ...           ...
# 2021-05-24  81.9360   1982.0000  82.9977   2008.0000  6246925.0000
# 2021-05-25  81.8111   1960.0000  82.4356   1996.4000  7578668.0000
# 2021-05-26  81.4364   1965.3000  81.9360   1975.0000  9650686.0000
# 2021-05-27  84.8712   1962.2500  84.9336   1970.3000 29557250.0000
# 2021-05-28  87.6190   1990.0000  89.2428   1990.0000 11620575.0000
#
#
#              RELIANCE.NS
# Date
# 2014-10-01  3994855.0000
# 2014-10-02           NaN
# 2014-10-03           NaN
# 2014-10-06           NaN
# 2014-10-07  5724531.0000
# ...                  ...
# 2021-05-24  3946636.0000
# 2021-05-25  6821015.0000
# 2021-05-26  3452113.0000
# 2021-05-27 12377100.0000
# 2021-05-28 26060864.0000
#
# [1724 rows x 12 columns]

# %%
close = df.Close.copy()
close
# Out:
#                  GE  RELIANCE.NS
# Date
# 2014-10-01 151.0839     459.2468
# 2014-10-02 150.8437          NaN
# 2014-10-03 152.5251          NaN
# 2014-10-06 151.4442          NaN
# 2014-10-07 148.9822     458.7267
# ...             ...          ...
# 2021-05-24  82.3107    1985.6500
# 2021-05-25  81.9360    1963.1500
# 2021-05-26  83.6846    1970.0500
# 2021-05-27  89.6175    1976.1000
# 2021-05-28  87.8064    2094.8000
#
# [1724 rows x 2 columns]

# %%
close.GE.dropna().plot(figsize=(15, 8), fontsize=13)
plt.legend(fontsize= 13)
plt.show()

# %%
norm = close.div(close.iloc[0]).mul(1)
norm
# Out:
#                GE  RELIANCE.NS
# Date
# 2014-10-01 1.0000       1.0000
# 2014-10-02 0.9984          NaN
# 2014-10-03 1.0095          NaN
# 2014-10-06 1.0024          NaN
# 2014-10-07 0.9861       0.9989
# ...           ...          ...
# 2021-05-24 0.5448       4.3237
# 2021-05-25 0.5423       4.2747
# 2021-05-26 0.5539       4.2897
# 2021-05-27 0.5932       4.3029
# 2021-05-28 0.5812       4.5614
#
# [1724 rows x 2 columns]

# %%
norm.dropna().plot(figsize=(15, 8), fontsize=13)
plt.legend(fontsize= 13)
plt.show()
